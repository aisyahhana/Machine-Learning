# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
x = data.drop('Survived', axis=1)
y = data['Survoved']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

slaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#membuat model nerual network degnan 2 hidden laye
model = Sequential

model.add(Dense(16, activations='relu', input_shape=(x_train.shape{1})))
model.add(Dense(6, activations='relu'))
model.add(Dense(1  activations='sigmoid'))

model.summary

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#training model
history = model.fit(x_train, y_train, epochs=2

# %%
#evaluasi model
loss, accuracy = model.evaluate(x_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
